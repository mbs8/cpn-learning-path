# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file that's in my current directory and summarize its contents
    """,
)

run_conversation(messages)
# Out:
# I'll open and view the main.py file for you.
# abs_path: /home/matheusb/Projects/Github/cpn-learning-path/2-build-with-claude/4-tools-with-claude/005_text_editor_tool/main.py
# ## Summary of main.py
#
# This is a simple Python file containing:
#
# - **A single function** called `greeting()` that prints "Hello World!" to the console when called.
#
# The file is minimal and appears to be a basic example or starter code. The function itself is not called anywhere in the file, so simply running this script wouldn't produce any output - you would need to explicitly call `greeting()` for it to execute.
# [{'role': 'user',
#   'content': "\n    Open the ./main.py file that's in my current directory and summarize its contents\n    "},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll open and view the main.py file for you.", type='text'),
#    ToolUseBlock(id='toolu_01KdRF38MtksPzBko1wiZxap', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01KdRF38MtksPzBko1wiZxap',
#     'content': '"1: def greeting():\\n2:     print(\\"Hello World!\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='## Summary of main.py\n\nThis is a simple Python file containing:\n\n- **A single function** called `greeting()` that prints "Hello World!" to the console when called.\n\nThe file is minimal and appears to be a basic example or starter code. The function itself is not called anywhere in the file, so simply running this script wouldn\'t produce any output - you would need to explicitly call `greeting()` for it to execute.', type='text')]}]

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calculate pi to the 5th digit. Then create a ./test.py file to test your implementation.
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit and then write tests for it.
# abs_path: /home/matheusb/Projects/Github/cpn-learning-path/2-build-with-claude/4-tools-with-claude/005_text_editor_tool
#
# abs_path: /home/matheusb/Projects/Github/cpn-learning-path/2-build-with-claude/4-tools-with-claude/005_text_editor_tool/main.py
# Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula or a more efficient algorithm like the Chudnovsky algorithm. For simplicity and reasonable accuracy, I'll use the Machin formula which converges quickly.
# Now let's create a test file to test the implementation:
# Perfect! Let me verify the files were created correctly:
# abs_path: /home/matheusb/Projects/Github/cpn-learning-path/2-build-with-claude/4-tools-with-claude/005_text_editor_tool/main.py
# Excellent! I've successfully:
#
# ## 1. **Created the `calculate_pi()` function in `./main.py`**
#    - Uses the **Machin formula** for efficient calculation: π/4 = 4×arctan(1/5) - arctan(1/239)
#    - Implements arctan using Taylor series expansion
#    - Uses Python's `Decimal` module for high precision arithmetic
#    - Defaults to 5 decimal digits but can calculate to higher precision
#    - Returns pi as a float (approximately 3.14159 for 5 digits)
#
# ## 2. **Created comprehensive tests in `./test.py`**
#    The test suite includes:
#    - **test_pi_to_5_digits**: Verifies pi is accurate to 5 decimal places (3.14159)
#    - **test_pi_matches_math_library**: Compares against Python's math.pi
#    - **test_pi_first_digit**: Checks the integer part is 3
#    - **test_pi_range**: Ensures the value is in the correct range
#    - **test_higher_precision**: Tests calculation with 10 digits
#    - **test_return_type**: Validates the return type is float
#
# You can run the tests by executing:
# ```bash
# python test.py
# ```
#
# The implementation is accurate and efficient, converging quickly to the correct value of π = 3.14159265...
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate pi to the 5th digit. Then create a ./test.py file to test your implementation.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit and then write tests for it.", type='text'),
#    ToolUseBlock(id='toolu_01VegTBdtWGyYU39h9F16Ndj', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01VegTBdtWGyYU39h9F16Ndj',
#     'content': '"005_text_editor_tool.ipynb\\nmain.py\\n.backups"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_016h9EYtXjDje3rmti5tdgMK', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_016h9EYtXjDje3rmti5tdgMK',
#     'content': '"1: def greeting():\\n2:     print(\\"Hello World!\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula or a more efficient algorithm like the Chudnovsky algorithm. For simplicity and reasonable accuracy, I'll use the Machin formula which converges quickly.", type='text'),
#    ToolUseBlock(id='toolu_01PuwGMAYSuCUadL5UUX58zY', caller=DirectCaller(type='direct'), input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def greeting():\n    print("Hello World!")', 'new_str': 'def greeting():\n    print("Hello World!")\n\n\ndef calculate_pi(digits=5):\n    """\n    Calculate pi to a specified number of decimal digits using the Machin formula.\n    Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    \n    Args:\n        digits: Number of decimal digits of accuracy (default: 5)\n    \n    Returns:\n        float: Approximation of pi\n    """\n    from decimal import Decimal, getcontext\n    \n    # Set precision high enough for the calculation\n    getcontext().prec = digits + 10\n    \n    def arctan(x, num_terms=100):\n        """Calculate arctan using Taylor series expansion"""\n        x = Decimal(x)\n        power = x\n        result = power\n        for n in range(1, num_terms):\n            power *= -x * x\n            result += power / (2 * n + 1)\n        return result\n    \n    # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    pi = 4 * (4 * arctan(Decimal(1) / Decimal(5)) - arctan(Decimal(1) / Decimal(239)))\n    \n    return float(pi)'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01PuwGMAYSuCUadL5UUX58zY',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now let's create a test file to test the implementation:", type='text'),
#    ToolUseBlock(id='toolu_0137ViNwScvZjRubgDwk9DSe', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './test.py', 'file_text': 'import unittest\nimport math\nfrom main import calculate_pi\n\n\nclass TestPiCalculation(unittest.TestCase):\n    """Test cases for the calculate_pi function"""\n    \n    def test_pi_to_5_digits(self):\n        """Test that pi is calculated accurately to 5 decimal places"""\n        calculated_pi = calculate_pi(5)\n        expected_pi = 3.14159  # Pi to 5 decimal places\n        \n        # Check if the result matches to 5 decimal places\n        self.assertAlmostEqual(calculated_pi, expected_pi, places=5,\n                              msg=f"Expected {expected_pi}, got {calculated_pi}")\n    \n    def test_pi_matches_math_library(self):\n        """Test that our calculation is close to math.pi"""\n        calculated_pi = calculate_pi(5)\n        \n        # Should be very close to the standard library value\n        self.assertAlmostEqual(calculated_pi, math.pi, places=5,\n                              msg=f"Expected {math.pi}, got {calculated_pi}")\n    \n    def test_pi_first_digit(self):\n        """Test that the integer part is 3"""\n        calculated_pi = calculate_pi(5)\n        self.assertEqual(int(calculated_pi), 3,\n                        msg=f"Integer part should be 3, got {int(calculated_pi)}")\n    \n    def test_pi_range(self):\n        """Test that pi is in the expected range"""\n        calculated_pi = calculate_pi(5)\n        self.assertGreater(calculated_pi, 3.14159,\n                          msg=f"Pi should be greater than 3.14159, got {calculated_pi}")\n        self.assertLess(calculated_pi, 3.14160,\n                       msg=f"Pi should be less than 3.14160, got {calculated_pi}")\n    \n    def test_higher_precision(self):\n        """Test calculation with higher precision"""\n        calculated_pi = calculate_pi(10)\n        expected_pi = 3.1415926536  # Pi to 10 decimal places\n        \n        self.assertAlmostEqual(calculated_pi, expected_pi, places=9,\n                              msg=f"Expected {expected_pi}, got {calculated_pi}")\n    \n    def test_return_type(self):\n        """Test that the function returns a float"""\n        result = calculate_pi(5)\n        self.assertIsInstance(result, float,\n                             msg=f"Expected float, got {type(result)}")\n\n\nif __name__ == \'__main__\':\n    # Run the tests\n    unittest.main(verbosity=2)\n'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_0137ViNwScvZjRubgDwk9DSe',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Perfect! Let me verify the files were created correctly:', type='text'),
#    ToolUseBlock(id='toolu_01GZfphGgiaH8dv8Mr2DxNtt', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01GZfphGgiaH8dv8Mr2DxNtt',
#     'content': '"1: def greeting():\\n2:     print(\\"Hello World!\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     Calculate pi to a specified number of decimal digits using the Machin formula.\\n8:     Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n9:     \\n10:     Args:\\n11:         digits: Number of decimal digits of accuracy (default: 5)\\n12:     \\n13:     Returns:\\n14:         float: Approximation of pi\\n15:     \\"\\"\\"\\n16:     from decimal import Decimal, getcontext\\n17:     \\n18:     # Set precision high enough for the calculation\\n19:     getcontext().prec = digits + 10\\n20:     \\n21:     def arctan(x, num_terms=100):\\n22:         \\"\\"\\"Calculate arctan using Taylor series expansion\\"\\"\\"\\n23:         x = Decimal(x)\\n24:         power = x\\n25:         result = power\\n26:         for n in range(1, num_terms):\\n27:             power *= -x * x\\n28:             result += power / (2 * n + 1)\\n29:         return result\\n30:     \\n31:     # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n32:     pi = 4 * (4 * arctan(Decimal(1) / Decimal(5)) - arctan(Decimal(1) / Decimal(239)))\\n33:     \\n34:     return float(pi)"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Excellent! I've successfully:\n\n## 1. **Created the `calculate_pi()` function in `./main.py`**\n   - Uses the **Machin formula** for efficient calculation: π/4 = 4×arctan(1/5) - arctan(1/239)\n   - Implements arctan using Taylor series expansion\n   - Uses Python's `Decimal` module for high precision arithmetic\n   - Defaults to 5 decimal digits but can calculate to higher precision\n   - Returns pi as a float (approximately 3.14159 for 5 digits)\n\n## 2. **Created comprehensive tests in `./test.py`**\n   The test suite includes:\n   - **test_pi_to_5_digits**: Verifies pi is accurate to 5 decimal places (3.14159)\n   - **test_pi_matches_math_library**: Compares against Python's math.pi\n   - **test_pi_first_digit**: Checks the integer part is 3\n   - **test_pi_range**: Ensures the value is in the correct range\n   - **test_higher_precision**: Tests calculation with 10 digits\n   - **test_return_type**: Validates the return type is float\n\nYou can run the tests by executing:\n```bash\npython test.py\n```\n\nThe implementation is accurate and efficient, converging quickly to the correct value of π = 3.14159265...", type='text')]}]
